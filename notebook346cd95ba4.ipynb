# %%
import os
os.getcwd()
# Out:
# '/kaggle/working'

# %%
# !git clone https://github.com/wkim97/FSR.git
# Out:
# Cloning into 'FSR'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 55 (delta 15), reused 46 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 63.85 KiB | 1.64 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
os.chdir('/kaggle/working/FSR')

# %%
# Install gdown if it's not already installed
# !pip install gdown

import gdown

# Google Drive file ID
file_id = '1-p7zZjRTwJfk-iOu1iCqXeojxPZ28c0C'

# Construct the URL
url = f'https://drive.google.com/uc?id={file_id}'

# Download the file to the specified directory
output_path = '/kaggle/working/FSR/train.py'
gdown.download(url, output_path, quiet=False)
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1-p7zZjRTwJfk-iOu1iCqXeojxPZ28c0C
# From (redirected): https://drive.google.com/uc?id=1-p7zZjRTwJfk-iOu1iCqXeojxPZ28c0C&confirm=t&uuid=ef4f1ba9-dfaa-4727-8c0d-c33291bceb6d
# To: /kaggle/working/FSR/train.py
# 100%|██████████| 11.9k/11.9k [00:00<00:00, 16.1MB/s]
# '/kaggle/working/FSR/train.py'

# %%
folder_path = '/kaggle/working/FSR/weights/cifar10/wideresnet34/'

# Create the directory if it doesn't exist
os.makedirs(folder_path, exist_ok=True)
print(f"Directory '{folder_path}' is created/existed successfully.")
# Out:
# Directory '/kaggle/working/FSR/weights/cifar10/wideresnet34/' is created/existed successfully.

# %%
file_id = '1vFgZf3j_dSIxMj12l9mwfI3cYP6Bjzd2'
# Construct the URL
url = f'https://drive.google.com/uc?id={file_id}'
# Download the file to the specified directory
output_path = '/kaggle/working/FSR/weights/cifar10/wideresnet34/cifar10_wideresnet34_epoch67.pth'
gdown.download(url, output_path, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1vFgZf3j_dSIxMj12l9mwfI3cYP6Bjzd2
# From (redirected): https://drive.google.com/uc?id=1vFgZf3j_dSIxMj12l9mwfI3cYP6Bjzd2&confirm=t&uuid=7725b9d9-e2cd-4107-9b26-81cc8687dbf2
# To: /kaggle/working/FSR/weights/cifar10/wideresnet34/cifar10_wideresnet34_epoch67.pth
# 100%|██████████| 390M/390M [00:02<00:00, 156MB/s]
# '/kaggle/working/FSR/weights/cifar10/wideresnet34/cifar10_wideresnet34_epoch67.pth'

# %%
# !python train.py \
--save_name cifar10_wideresnet34 --dataset cifar10 --model wideresnet34 --device 0 --epoch 30 --resume True \
--save_freq 5
# Out:
# ...
# 100%|███████████████████████| 170498071/170498071 [00:11<00:00, 14467852.40it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Checkpoint directory exists: ./weights/cifar10/wideresnet34
# Loading checkpoint './weights/cifar10/wideresnet34/cifar10_wideresnet34_epoch67.pth'
# Checkpoint loaded successfully.
# Model state_dict loaded.
# Optimizer state_dict loaded.
# Resuming training from epoch 68.
#
# Epoch: 68
# cifar10_wideresnet34 (Train) Epoch: 68/97:   2%| | 768/49920 [00:23<19:46, 41.42^C
# cifar10_wideresnet34 (Train) Epoch: 68/97:   2%| | 768/49920 [00:25<27:27, 29.84
# Traceback (most recent call last):
#   File "/kaggle/working/FSR/train.py", line 307, in <module>
#     train(epoch)
#   File "/kaggle/working/FSR/train.py", line 204, in train
#     adv_inputs = attack.perturb(inputs, targets, True)
#   File "/kaggle/working/FSR/attacks/pgd.py", line 56, in perturb
# ...
